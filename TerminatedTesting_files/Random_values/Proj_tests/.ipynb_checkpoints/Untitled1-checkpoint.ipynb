# %%
import copy
SubByte = [
    ['63', '7C', '77', '7B', 'F2', '6B', '6F', 'C5', '30', '01', '67', '2B', 'FE', 'D7', 'AB', '76'],
    ['CA', '82', 'C9', '7D', 'FA', '59', '47', 'F0', 'AD', 'D4', 'A2', 'AF', '9C', 'A4', '72', 'C0'],
    ['B7', 'FD', '93', '26', '36', '3F', 'F7', 'CC', '34', 'A5', 'E5', 'F1', '71', 'D8', '31', '15'],
    ['04', 'C7', '23', 'C3', '18', '96', '05', '9A', '07', '12', '80', 'E2', 'EB', '27', 'B2', '75'],
    ['09', '83', '2C', '1A', '1B', '6E', '5A', 'A0', '52', '3B', 'D6', 'B3', '29', 'E3', '2F', '84'],
    ['53', 'D1', '00', 'ED', '20', 'FC', 'B1', '5B', '6A', 'CB', 'BE', '39', '4A', '4C', '58', 'CF'],
    ['D0', 'EF', 'AA', 'FB', '43', '4D', '33', '85', '45', 'F9', '02', '7F', '50', '3C', '9F', 'A8'],
    ['51', 'A3', '40', '8F', '92', '9D', '38', 'F5', 'BC', 'B6', 'DA', '21', '10', 'FF', 'F3', 'D2'],
    ['CD', '0C', '13', 'EC', '5F', '97', '44', '17', 'C4', 'A7', '7E', '3D', '64', '5D', '19', '73'],
    ['60', '81', '4F', 'DC', '22', '2A', '90', '88', '46', 'EE', 'B8', '14', 'DE', '5E', '0B', 'DB'],
    ['E0', '32', '3A', '0A', '49', '06', '24', '5C', 'C2', 'D3', 'AC', '62', '91', '95', 'E4', '79'],
    ['E7', 'C8', '37', '6D', '8D', 'D5', '4E', 'A9', '6C', '56', 'F4', 'EA', '65', '7A', 'AE', '08'],
    ['BA', '78', '25', '2E', '1C', 'A6', 'B4', 'C6', 'E8', 'DD', '74', '1F', '4B', 'BD', '8B', '8A'],
    ['70', '3E', 'B5', '66', '48', '03', 'F6', '0E', '61', '35', '57', 'B9', '86', 'C1', '1D', '9E'],
    ['E1', 'F8', '98', '11', '69', 'D9', '8E', '94', '9B', '1E', '87', 'E9', 'CE', '55', '28', 'DF'],
    ['8C', 'A1', '89', '0D', 'BF', 'E6', '42', '68', '41', '99', '2D', '0F', 'B0', '54', 'BB', '16']
]
def hexadecimal1(x):
    
    z=str(hex(ord(x))).split('x')
   #normally length are >2 no need to do this 
    if(len(z[1]) != 2):
        z[1] = '0'+z[1]
    #print(z[1].upper())
    return(z[1].upper())
def XOR(x, y):
    z = []
    for i in range(4):
        temp = str(hex(int(x[i],16)^int(y[i],16)).split('x')[-1]).upper()
        if(len(temp) != 2):
            temp = '0'+temp
        
        z.append(temp)
    return z
def EntendKey(KEY):
    l1 = list(KEY)
    l2 = [hexadecimal1(i) for i in l1]
    print(l2)
    roundKey = []
    roundKey.append(l2)
    print(roundKey)
    print("\n\n")
    
    RC = ['01', '02', '04', '08', '10', '20', '40', '80', '1B', '36']
    rc = [int(i,16) for i in RC]
    
    
    print(RC)
    print(rc)
    for i in range(10):
        w3 = [roundKey[-1][13], roundKey[-1][14], roundKey[-1][15], roundKey[-1][12]]
        subtituteByte = []
        print("hello\n",w3)
        print("\n")
        for j in range(4):
            s1 = int(w3[j][0],16)
            s2 = int(w3[j][1],16)
            subtituteByte.append(SubByte[s1][s2])


        subtituteByte[0] = str(hex(int(subtituteByte[0],16)^int(rc[i]))).split('x')[-1].upper()

        if len(subtituteByte[0]) != 2:
            subtituteByte[0] = '0'+subtituteByte[0]

        
        w4 = XOR(roundKey[-1][0:4],subtituteByte)
        w5 = XOR(roundKey[-1][4:8], w4)
        w6 = XOR(roundKey[-1][8:12], w5)
        w7 = XOR(roundKey[-1][12:16], w6)
        w_final = w4 + w5 + w6 + w7
        roundKey.append(w_final)
    return roundKey


msg= ('hello and namaste')
#msg = 'Two One Nine Two'
KEY = ('two one nine two')
roundKey = EntendKey(KEY)
print(roundKey)
# Out:
# ['74', '77', '6F', '20', '6F', '6E', '65', '20', '6E', '69', '6E', '65', '20', '74', '77', '6F']
# [['74', '77', '6F', '20', '6F', '6E', '65', '20', '6E', '69', '6E', '65', '20', '74', '77', '6F']]
#
#
#
# ['01', '02', '04', '08', '10', '20', '40', '80', '1B', '36']
# [1, 2, 4, 8, 16, 32, 64, 128, 27, 54]
# hello
#  ['74', '77', '6F', '20']
#
#
# ['93', 'F5', 'A8', 'B7']
# hello
#  ['F1', 'BB', 'BD', 'C6']
#
#
# ['A3', 'EA', '7A', 'B4']
# hello
#  ['F0', '68', 'FB', 'EC']
#
#
# ['88', '45', '0F', 'CE']
# hello
#  ['58', '16', 'C4', 'C6']
#
#
# ['62', '47', '1C', 'B4']
# hello
#  ['33', '6B', 'DB', '42']
#
#
# ['D3', '7F', 'B9', '2C']
# hello
#  ['8E', '02', '91', '15']
#
#
# ['39', '77', '81', '59']
# hello
#  ['87', 'E9', 'A2', 'D5']
#
#
# ['57', '1E', '3A', '03']
# hello
#  ['46', '2C', 'C7', '91']
#
#
# ['DA', '71', 'C6', '81']
# hello
#  ['42', 'AD', '5A', '98']
#
#
# ['37', '95', 'BE', '46']
# hello
#  ['1B', 'BC', 'D7', '22']
#
#
# ['99', '65', '0E', '93']
# [['74', '77', '6F', '20', '6F', '6E', '65', '20', '6E', '69', '6E', '65', '20', '74', '77', '6F'], ['E7', '82', 'C7', '97', '88', 'EC', 'A2', 'B7', 'E6', '85', 'CC', 'D2', 'C6', 'F1', 'BB', 'BD'], ['44', '68', 'BD', '23', 'CC', '84', '1F', '94', '2A', '01', 'D3', '46', 'EC', 'F0', '68', 'FB'], ['CC', '2D', 'B2', 'ED', '00', 'A9', 'AD', '79', '2A', 'A8', '7E', '3F', 'C6', '58', '16', 'C4'], ['AE', '6A', 'AE', '59', 'AE', 'C3', '03', '20', '84', '6B', '7D', '1F', '42', '33', '6B', 'DB'], ['7D', '15', '17', '75', 'D3', 'D6', '14', '55', '57', 'BD', '69', '4A', '15', '8E', '02', '91'], ['44', '62', '96', '2C', '97', 'B4', '82', '79', 'C0', '09', 'EB', '33', 'D5', '87', 'E9', 'A2'], ['13', '7C', 'AC', '2F', '84', 'C8', '2E', '56', '44', 'C1', 'C5', '65', '91', '46', '2C', 'C7'], ['C9', '0D', '6A', 'AE', '4D', 'C5', '44', 'F8', '09', '04', '81', '9D', '98', '42', 'AD', '5A'], ['FE', '98', 'D4', 'E8', 'B3', '5D', '90', '10', 'BA', '59', '11', '8D', '22', '1B', 'BC', 'D7'], ['67', 'FD', 'DA', '7B', 'D4', 'A0', '4A', '6B', '6E', 'F9', '5B', 'E6', '4C', 'E2', 'E7', '31']]
